# %% [markdown]
# # Импорты

# %%
import torch

# %%
# %pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.49.1-cp310-cp310-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from shap) (2.2.6)
# Requirement already satisfied: scipy in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from shap) (1.15.3)
# Requirement already satisfied: scikit-learn in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from shap) (1.7.2)
# Requirement already satisfied: pandas in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from shap) (2.3.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from shap) (25.0)
# Collecting slicer==0.0.8 (from shap)
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba>=0.54 (from shap)
#   Downloading numba-0.63.1-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Collecting cloudpickle (from shap)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from shap) (4.15.0)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.54->shap)
#   Downloading llvmlite-0.46.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: colorama in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\knefpc\miniconda3\envs\jupgpu\lib\site-packages (from scikit-learn->shap) (3.6.0)
# Downloading shap-0.49.1-cp310-cp310-win_amd64.whl (547 kB)
#    ---------------------------------------- 0.0/547.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/547.0 kB ? eta -:--:--
#    ---------------------------------------- 547.0/547.0 kB 3.7 MB/s  0:00:00
# Using cached slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading numba-0.63.1-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------------------ --------- 2.1/2.7 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 10.6 MB/s  0:00:00
# Downloading llvmlite-0.46.0-cp310-cp310-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    --- ------------------------------------ 3.7/38.1 MB 16.8 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/38.1 MB 29.7 MB/s eta 0:00:01
#    ------------------------- -------------- 24.4/38.1 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.8/38.1 MB 40.0 MB/s eta 0:00:01
#    -------------------------------------- - 36.4/38.1 MB 39.3 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.1 MB 31.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 29.9 MB/s  0:00:01
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Installing collected packages: slicer, llvmlite, cloudpickle, numba, shap
#
#    -------- ------------------------------- 1/5 [llvmlite]
#    -------- ------------------------------- 1/5 [llvmlite]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    ------------------------ --------------- 3/5 [numba]
#    -------------------------------- ------- 4/5 [shap]
#    -------------------------------- ------- 4/5 [shap]
#    ---------------------------------------- 5/5 [shap]
#
# Successfully installed cloudpickle-3.1.2 llvmlite-0.46.0 numba-0.63.1 shap-0.49.1 slicer-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install catboost
# !pip install optuna
# !pip install category_encoders
# !pip install xgboost
# !pip install lightgbm
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: catboost in c:\users\knefpc\miniconda3\lib\site-packages (1.2.8)
# Requirement already satisfied: graphviz in c:\users\knefpc\miniconda3\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\knefpc\miniconda3\lib\site-packages (from catboost) (3.10.8)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\knefpc\miniconda3\lib\site-packages (from catboost) (2.3.5)
# Requirement already satisfied: pandas>=0.24 in c:\users\knefpc\miniconda3\lib\site-packages (from catboost) (2.3.3)
# Requirement already satisfied: scipy in c:\users\knefpc\miniconda3\lib\site-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in c:\users\knefpc\miniconda3\lib\site-packages (from catboost) (6.5.0)
# Requirement already satisfied: six in c:\users\knefpc\miniconda3\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\knefpc\miniconda3\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\knefpc\miniconda3\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\knefpc\miniconda3\lib\site-packages (from pandas>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib->catboost) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib->catboost) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\knefpc\miniconda3\lib\site-packages (from plotly->catboost) (2.13.0)
# Requirement already satisfied: optuna in c:\users\knefpc\miniconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\knefpc\miniconda3\lib\site-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in c:\users\knefpc\miniconda3\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in c:\users\knefpc\miniconda3\lib\site-packages (from optuna) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\knefpc\miniconda3\lib\site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\knefpc\miniconda3\lib\site-packages (from optuna) (2.0.45)
# Requirement already satisfied: tqdm in c:\users\knefpc\miniconda3\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\knefpc\miniconda3\lib\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in c:\users\knefpc\miniconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\knefpc\miniconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in c:\users\knefpc\miniconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.3.0)
# Requirement already satisfied: colorama in c:\users\knefpc\miniconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\knefpc\miniconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Requirement already satisfied: category_encoders in c:\users\knefpc\miniconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\knefpc\miniconda3\lib\site-packages (from category_encoders) (2.3.5)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\knefpc\miniconda3\lib\site-packages (from category_encoders) (2.3.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\knefpc\miniconda3\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\knefpc\miniconda3\lib\site-packages (from category_encoders) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\knefpc\miniconda3\lib\site-packages (from category_encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\knefpc\miniconda3\lib\site-packages (from category_encoders) (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\knefpc\miniconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\knefpc\miniconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\knefpc\miniconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\knefpc\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\knefpc\miniconda3\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\knefpc\miniconda3\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\knefpc\miniconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Requirement already satisfied: xgboost in c:\users\knefpc\miniconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\users\knefpc\miniconda3\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\knefpc\miniconda3\lib\site-packages (from xgboost) (1.16.3)
# Requirement already satisfied: lightgbm in c:\users\knefpc\miniconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\knefpc\miniconda3\lib\site-packages (from lightgbm) (2.3.5)
# Requirement already satisfied: scipy in c:\users\knefpc\miniconda3\lib\site-packages (from lightgbm) (1.16.3)
# Requirement already satisfied: imbalanced-learn in c:\users\knefpc\miniconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\knefpc\miniconda3\lib\site-packages (from imbalanced-learn) (2.3.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\knefpc\miniconda3\lib\site-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\knefpc\miniconda3\lib\site-packages (from imbalanced-learn) (1.8.0)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\knefpc\miniconda3\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\knefpc\miniconda3\lib\site-packages (from imbalanced-learn) (3.6.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\knefpc\miniconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\knefpc\miniconda3\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\knefpc\miniconda3\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\knefpc\miniconda3\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\knefpc\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\knefpc\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\knefpc\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\knefpc\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score, fbeta_score, roc_auc_score, classification_report, precision_recall_curve, roc_curve, roc_auc_score, precision_recall_curve, auc
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
import optuna
from optuna.samplers import TPESampler
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import VotingClassifier, StackingClassifier
from optuna.pruners import SuccessiveHalvingPruner
import lightgbm as lgb
import category_encoders as ce
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# %%
# !pip install google
# Out:
# Requirement already satisfied: google in c:\users\knefpc\miniconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\knefpc\miniconda3\lib\site-packages (from google) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\knefpc\miniconda3\lib\site-packages (from beautifulsoup4->google) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\knefpc\miniconda3\lib\site-packages (from beautifulsoup4->google) (4.15.0)

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\knefpc\miniconda3\lib\site-packages (1.8.2)
# Requirement already satisfied: black>=24.10.0 in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (1.19.0)
# Requirement already satisfied: protobuf in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-dateutil in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\knefpc\miniconda3\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\knefpc\miniconda3\lib\site-packages (from black>=24.10.0->kaggle) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\knefpc\miniconda3\lib\site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\knefpc\miniconda3\lib\site-packages (from black>=24.10.0->kaggle) (25.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\knefpc\miniconda3\lib\site-packages (from black>=24.10.0->kaggle) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\knefpc\miniconda3\lib\site-packages (from black>=24.10.0->kaggle) (4.5.0)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\knefpc\miniconda3\lib\site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: colorama in c:\users\knefpc\miniconda3\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\knefpc\miniconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in c:\users\knefpc\miniconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.3)
# Requirement already satisfied: webencodings in c:\users\knefpc\miniconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\knefpc\miniconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\knefpc\miniconda3\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\knefpc\miniconda3\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\knefpc\miniconda3\lib\site-packages (from requests->kaggle) (2025.10.5)

# %%
# !kaggle competitions download -c gamma-knife-3
# Out:
# gamma-knife-3.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import os

zip_path = "gamma-knife-3.zip"
extract_path = "gamma-knife-3"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Готово, распаковано в папку:", extract_path)
# Out:
# Готово, распаковано в папку: gamma-knife-3

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("gamma-knife-3/train.csv")
df_test = pd.read_csv("gamma-knife-3/test.csv")
df.head()

df_test['Объем максимального очага'] = df_test['Объем максимального очага'].str.replace(',', '.').astype('float')
df_test['Суммарный объем очагов'] = df_test['Суммарный объем очагов'].str.replace(',', '.').astype('float')
df_test.head()
# Out:
#    ID Пол Дата рождения Онкологический диагноз  \
# 0   1   Ж    28.05.1924                   НМРЛ
# 1   2   М    12.03.1930               Меланома
# 2   3   Ж    08.10.1934               Меланома
# 3   4   Ж    25.04.1936                    РМЖ
# 4   5   Ж    21.06.1938                     РП
#
#   Дата постановки онкологического диагноза / начала первичного лечения  \
# 0                                         01.06.2011
# 1                                         01.01.2009
# 2                                         01.02.2010
# 3                                         01.12.2004
# 4                                         01.08.2007
#
#   Дата удаления первичного очага Дата развития МГМ Активирующие мутации  \
# 0                      не удален        01.07.2011                  NaN
# 1                     01.01.2009        01.01.2010                  NaN
# 2                     01.02.2010        01.10.2010                  NaN
# 3                            NaN        05.07.2013                  нет
# 4                      не удален        13.08.2008                  NaN
#
#   Дата проведения ОВГМ Дата операции на ГМ  Число РХ процедур на ГН  \
# 0                  нет                 нет                        2
# 1                  нет                 нет                        2
# 2                  нет                 нет                        1
# 3                  нет                 нет                        1
# 4                  нет                 нет                        1
#
#   Дата 1-ой РХ  Индекс Карновского  Число очагов в ГМ  Суммарный объем очагов  \
# 0   26.09.2011                  70                  8                   11.57
# 1   01.03.2010                  80                  2                    4.60
# 2   10.11.2010                  80                  1                    4.40
# 3   18.07.2013                  60                  7                    8.72
# 4   29.09.2008                  70                  2                    5.60
#
#    Объем максимального очага Экстракраниальные метастазы Лекарственное лечение
# 0                       7.10                         NaN          Химиотерапия
# 1                       2.70                         NaN           Без лечения
# 2                       4.40                         NaN          Химиотерапия
# 3                       7.26                        есть          Химиотерапия
# 4                       4.00                        есть          Химиотерапия

# %%
dates = ['Дата рождения', 'Дата постановки онкологического диагноза / начала первичного лечения', 'Дата удаления первичного очага', 'Дата развития МГМ', 'Дата проведения ОВГМ', 'Дата операции на ГМ', 'Дата 1-ой РХ']

for date in dates:
  df[date] = pd.to_datetime(df[date], format = '%d.%m.%Y', errors = 'coerce')
  df_test[date] = pd.to_datetime(df_test[date], format = '%d.%m.%Y', errors = 'coerce')

# %%
df['Пол'].value_counts()
df['Пол'] = df['Пол'].replace('м', 'М').replace('ж', 'Ж')

df['Мужчина'] = df['Пол'].apply(lambda x: 1 if x == 'М' else 0)

df.drop(columns = ['Пол'], axis = 1, inplace = True)

#Для итоговых данных

df_test['Пол'].value_counts()
df_test['Пол'] = df_test['Пол'].replace('м', 'М').replace('ж', 'Ж')

df_test['Мужчина'] = df_test['Пол'].apply(lambda x: 1 if x == 'М' else 0)

df_test.drop(columns = ['Пол'], axis = 1, inplace = True)

# %%
df['Возраст'] = (df['Дата 1-ой РХ'] - df['Дата рождения']).dt.days / 365.25
df['Время_метастазирования'] = (df['Дата развития МГМ'] - df['Дата постановки онкологического диагноза / начала первичного лечения']).dt.days
df['Время_реагирования'] = (df['Дата 1-ой РХ'] - df['Дата развития МГМ']).dt.days

df['ОВГМ'] = df['Дата проведения ОВГМ'].notna().astype(int)
df['Операция'] = df['Дата операции на ГМ'].notna().astype(int)

df.drop(columns = ['Дата рождения', 'Дата развития МГМ', 'Дата постановки онкологического диагноза / начала первичного лечения', 'Дата проведения ОВГМ', 'Дата операции на ГМ', 'Дата 1-ой РХ', 'Дата удаления первичного очага'], axis = 1, inplace = True)

#Для итоговых данных

df_test['Возраст'] = (df_test['Дата 1-ой РХ'] - df_test['Дата рождения']).dt.days / 365.25
df_test['Время_метастазирования'] = (df_test['Дата развития МГМ'] - df_test['Дата постановки онкологического диагноза / начала первичного лечения']).dt.days
df_test['Время_реагирования'] = (df_test['Дата 1-ой РХ'] - df_test['Дата развития МГМ']).dt.days

df_test['ОВГМ'] = df_test['Дата проведения ОВГМ'].notna().astype(int)
df_test['Операция'] = df_test['Дата операции на ГМ'].notna().astype(int)

df_test.drop(columns = ['Дата рождения', 'Дата развития МГМ', 'Дата постановки онкологического диагноза / начала первичного лечения', 'Дата проведения ОВГМ', 'Дата операции на ГМ', 'Дата 1-ой РХ', 'Дата удаления первичного очага'], axis = 1, inplace = True)

# %%
# Оставляем только строки с известной целевой переменной
df = df[df['Интракраниальная прогрессия'].notna()]

# Таргет
df['Прогрессия'] = df['Интракраниальная прогрессия'].apply(
    lambda x: 1 if x in ['ДМ', 'ЛР+ДМ', 'ЛР'] else 0
)

df.drop(columns=['Интракраниальная прогрессия', 'Активирующие мутации'], inplace=True)


def create_procedure_flag(series):
    """
    Бинарный флаг события/процедуры:
    - 1 если значение задано и это НЕ 'нет'
      (например дата или любое другое "да/есть/..." значение)
    - 0 если NaN/пусто или явно 'нет'
    """
    s = series.astype(str).str.strip().str.lower()

    # Nan после astype(str) станет 'nan' - считаем это пропуском
    is_missing = s.isin(['nan', 'none', ''])
    is_no = s.eq('нет')

    return (~is_missing & ~is_no).astype(int)


# train
df['Экстракраниальные метастазы'] = create_procedure_flag(df['Экстракраниальные метастазы'])
df['Дистантные метастазы'] = create_procedure_flag(df['Дистантные метастазы'])
df['Локальный рецидив'] = create_procedure_flag(df['Локальный рецидив'])

# test
df_test.drop(columns=['Активирующие мутации'], inplace=True)
df_test['Экстракраниальные метастазы'] = create_procedure_flag(df_test['Экстракраниальные метастазы'])
df_test['Дистантные метастазы'] = create_procedure_flag(df_test['Дистантные метастастазы']) if 'Дистантные метастастазы' in df_test.columns else df_test.get('Дистантные метастазы')
df_test['Локальный рецидив'] = create_procedure_flag(df_test['Локальный рецидив']) if 'Локальный рецидив' in df_test.columns else df_test.get('Локальный рецидив')

# %%
# OHE = ['Онкологический диагноз', 'Лекарственное лечение']
# df_encoded = pd.get_dummies(df, columns = OHE, prefix = '', prefix_sep='', dtype = 'int')
df_encoded = df.copy()

# %%
df_encoded['Суммарный объем очагов'] = df_encoded['Суммарный объем очагов'].str.replace(',', '.').astype('float')

# %%
df_encoded = df_encoded[(df_encoded['Время_метастазирования'].notna().astype(int) == 1) & (df_encoded['Время_реагирования'].notna().astype(int) == 1)]
df_encoded.drop(columns = ['Дистантные метастазы', 'Локальный рецидив'], axis = 1, inplace = True)

df_encoded['Объем на очаг'] = df_encoded['Суммарный объем очагов'] / df_encoded['Число очагов в ГМ']

#Для итоговых данных

df_test['Объем на очаг'] = df_test['Суммарный объем очагов'].astype('int') / df_test['Число очагов в ГМ']

# %%
df_encoded['Прогрессия'].value_counts()
df_encoded = df_encoded[df_encoded['Время_реагирования'] >= 0]

df_test = df_test[df_test['Время_реагирования'] >= 0]

# %%
df_encoded.drop(columns = ['Объем максимального очага'], axis = 1, inplace = True)
df_test.drop(columns = ['Объем максимального очага'], axis = 1, inplace = True)

# %%
cat_cols = ['Онкологический диагноз', 'Лекарственное лечение']
for col in cat_cols:
    df_encoded[col] = df_encoded[col].fillna("Unknown")

for col in cat_cols:
    df_test[col] = df_test[col].fillna("Unknown")

# %% [markdown]
# ### Новые признаки

# %%
df_encoded['Скорость_метастазирования'] = df_encoded['Суммарный объем очагов'] / df_encoded['Время_метастазирования']
df_encoded['Скорость_реагирования'] = df_encoded['Суммарный объем очагов'] / (df_encoded['Время_реагирования'] + 1)
df_encoded['Индекс_прогрессирования'] = df_encoded['Время_метастазирования'] - df_encoded['Время_реагирования']

df_test['Скорость_метастазирования'] = df_test['Суммарный объем очагов'] / df_test['Время_метастазирования']
df_test['Скорость_реагирования'] = df_test['Суммарный объем очагов'] / (df_test['Время_реагирования'] + 1)
df_test['Индекс_прогрессирования'] = df_test['Время_метастазирования'] - df_test['Время_реагирования']

# %%
p_99_TM = df_encoded['Время_метастазирования'].quantile(0.99)
df_encoded['Время_метастазирования'] = df_encoded['Время_метастазирования'].apply(lambda x: 0 if x < 0 else (p_99_TM if x > p_99_TM else x))

p_99_TR = df_encoded['Время_реагирования'].quantile(0.99)
df_encoded['Время_реагирования'] = df_encoded['Время_реагирования'].apply(lambda x: 0 if x < 0 else (p_99_TR if x > p_99_TR else x))

p_99_SV = df_encoded['Суммарный объем очагов'].quantile(0.99)
df_encoded['Суммарный объем очагов'] = df_encoded['Суммарный объем очагов'].apply(lambda x: 0 if x < 0 else (p_99_SV if x > p_99_SV else x))

p_99_VM = df_encoded['Объем на очаг'].quantile(0.99)
df_encoded['Объем на очаг'] = df_encoded['Объем на очаг'].apply(lambda x: 0 if x < 0 else (p_99_VM if x > p_99_VM else x))

#Итоговые

p_99_TM = df_test['Время_метастазирования'].quantile(0.99)
df_test['Время_метастазирования'] = df_test['Время_метастазирования'].apply(lambda x: 0 if x < 0 else (p_99_TM if x > p_99_TM else x))

p_99_TR = df_test['Время_реагирования'].quantile(0.99)
df_test['Время_реагирования'] = df_test['Время_реагирования'].apply(lambda x: 0 if x < 0 else (p_99_TR if x > p_99_TR else x))

p_99_SV = df_test['Суммарный объем очагов'].quantile(0.99)
df_test['Суммарный объем очагов'] = df_test['Суммарный объем очагов'].apply(lambda x: 0 if x < 0 else (p_99_SV if x > p_99_SV else x))

p_99_VM = df_test['Объем на очаг'].quantile(0.99)
df_test['Объем на очаг'] = df_test['Объем на очаг'].apply(lambda x: 0 if x < 0 else (p_99_VM if x > p_99_VM else x))

# %%
# train: приведение и логарифмы
df_encoded['Суммарный объем очагов'] = (
    df_encoded['Суммарный объем очагов']
    .apply(lambda x: str(x).replace(',', '.'))
    .astype(float)
)

df_encoded['Суммарный объем очагов'] = np.log1p(df_encoded['Суммарный объем очагов'])
df_encoded['Объем на очаг'] = np.log1p(df_encoded['Объем на очаг'])
df_encoded['Время_метастазирования'] = np.log1p(df_encoded['Время_метастазирования'])
df_encoded['Время_реагирования'] = np.log1p(df_encoded['Время_реагирования'])

df_encoded['Возраст * число очагов'] = df_encoded['Возраст'] * df_encoded['Число очагов в ГМ']

# test: приведение и логарифмы
df_test['Суммарный объем очагов'] = (
    df_test['Суммарный объем очагов']
    .apply(lambda x: str(x).replace(',', '.'))
    .astype(float)
)

df_test['Суммарный объем очагов'] = np.log1p(df_test['Суммарный объем очагов'])
df_test['Объем на очаг'] = np.log1p(df_test['Объем на очаг'])
df_test['Время_метастазирования'] = np.log1p(df_test['Время_метастазирования'])
df_test['Время_реагирования'] = np.log1p(df_test['Время_реагирования'])

df_test['Возраст * число очагов'] = df_test['Возраст'] * df_test['Число очагов в ГМ']

# qcut: границы считаем по train, применяем к test
cats_train, bin_edges = pd.qcut(
    df_encoded["Суммарный объем очагов"],
    q=[0, 0.25, 0.5, 0.75, 1.0],
    retbins=True,
    duplicates='drop'
)

labels = list(range(len(bin_edges) - 1))

df_encoded["Категория"] = pd.cut(
    df_encoded["Суммарный объем очагов"],
    bins=bin_edges,
    labels=labels,
    include_lowest=True
)

df_test["Категория"] = pd.cut(
    df_test["Суммарный объем очагов"],
    bins=bin_edges,
    labels=labels,
    include_lowest=True
)

# Если в тесте появились NaN (значения вне диапазона или из-за краёв), прижмём:
min_label, max_label = labels[0], labels[-1]

mask_nan = df_test["Категория"].isna()
if mask_nan.any():
    df_test.loc[mask_nan & (df_test["Суммарный объем очагов"] <= bin_edges[0]), "Категория"] = min_label
    df_test.loc[mask_nan & (df_test["Суммарный объем очагов"] >= bin_edges[-1]), "Категория"] = max_label
    # если вдруг остались NaN (например, из-за NaN в объёме) - заполним минимальным
    df_test["Категория"] = df_test["Категория"].fillna(min_label)

# приводим к int
df_encoded["Категория"] = df_encoded["Категория"].astype(int)
df_test["Категория"] = df_test["Категория"].astype(int)

# %%
df_encoded
# Out:
#     Онкологический диагноз  Число РХ процедур на ГН  Индекс Карновского  \
# 0                     НМРЛ                        1                  70
# 1                       РП                        3                  70
# 2                 Меланома                        1                  80
# 3                     НМРЛ                        1                  60
# 4                      КРР                        1                  80
# ..                     ...                      ...                 ...
# 864                    КРР                        1                  70
# 866               Меланома                        3                  80
# 867               Меланома                        1                  70
# 869                     РП                        1                  70
# 870                    РМЖ                        1                  80
#
#      Число очагов в ГМ  Суммарный объем очагов  Экстракраниальные метастазы  \
# 0                    1                1.974081                            0
# 1                    1                0.307485                            0
# 2                    3                0.350657                            1
# 3                    4                2.000128                            1
# 4                    3                1.871802                            1
# ..                 ...                     ...                          ...
# 864                  1                2.564949                            1
# 866                 19                1.108563                            1
# 867                 12                2.358965                            1
# 869                  4                1.241269                            1
# 870                  8                2.369309                            1
#
#     Лекарственное лечение  Мужчина    Возраст  Время_метастазирования  \
# 0            Химиотерапия        1  62.436687                5.981414
# 1       Таргетная терапия        1  62.023272                8.636042
# 2            Химиотерапия        1  52.298426                6.188264
# 3            Химиотерапия        1  55.383984                5.198497
# 4       Таргетная терапия        0  53.188227                6.885510
# ..                    ...      ...        ...                     ...
# 864          Химиотерапия        1  59.096509                6.413459
# 866     Таргетная терапия        0  35.879535                6.642487
# 867               Unknown        1  29.667351                4.094345
# 869     Таргетная терапия        0  55.364819                6.253829
# 870          Химиотерапия        0  61.106092                6.552508
#
#      Время_реагирования  ОВГМ  Операция  Прогрессия  Объем на очаг  \
# 0              5.267858     0         0           0       1.974081
# 1              7.178179     0         1           1       0.307485
# 2              4.867534     0         0           1       0.131028
# 3              3.828641     0         0           0       0.954549
# 4              6.298949     0         1           0       1.041454
# ..                  ...   ...       ...         ...            ...
# 864            3.555348     0         0           0       2.564949
# 866            0.000000     1         0           1       0.101511
# 867            3.465736     0         0           0       0.586860
# 869            3.737670     0         0           0       0.479335
# 870            6.142037     1         1           0       0.793558
#
#      Скорость_метастазирования  Скорость_реагирования  \
# 0                     0.015696               0.031959
# 1                     0.000064               0.000202
# 2                     0.000864               0.003231
# 3                     0.035500               0.138913
# 4                     0.005629               0.010110
# ..                         ...                    ...
# 864                   0.019704               0.342857
# 866                   0.002650               2.030000
# 867                   0.162373               0.299375
# 869                   0.004740               0.058571
# 870                   0.013843               0.020839
#
#      Индекс_прогрессирования  Возраст * число очагов  Категория
# 0                      202.0               62.436687          2
# 1                     3845.0               62.023272          0
# 2                      357.0              156.895277          0
# 3                      135.0              221.535934          2
# 4                      434.0              159.564682          2
# ..                       ...                     ...        ...
# 864                    575.0               59.096509          3
# 866                    766.0              681.711157          0
# 867                     28.0              356.008214          2
# 869                    478.0              221.459274          1
# 870                    236.0              488.848734          2
#
# [583 rows x 20 columns]

# %% [markdown]
# # Разделение данных

# %%
X = df_encoded.drop(columns=['Прогрессия'])
y = df_encoded['Прогрессия'].astype(int)

print("X shape:", X.shape, "| y mean:", y.mean())
# Out:
# X shape: (583, 19) | y mean: 0.6569468267581475

# %%
#"""Подготовка данных под CatBoost и LightGBM"""\

# CatBoost: категории строками
X_cb = X.copy()
test_cb = df_test.copy()

for c in cat_cols:
    X_cb[c] = X_cb[c].astype("object")
    test_cb[c] = test_cb[c].astype("object")

    X_cb[c] = X_cb[c].where(X_cb[c].notna(), "Unknown").astype(str)
    test_cb[c] = test_cb[c].where(test_cb[c].notna(), "Unknown").astype(str)

print("X_cb cat dtypes:")
print(X_cb[cat_cols].dtypes)
# Out:
# X_cb cat dtypes:
# Онкологический диагноз    object
# Лекарственное лечение     object
# dtype: object

# %% [markdown]
# # Данные под Catboost и LightGBM

# %% [markdown]
# # Optuna подбор параметров

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# ускоренный CV для тюнинга
CV = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# фикс индексов
X_cb = X_cb.reset_index(drop=True)
y = y.reset_index(drop=True)

def best_balanced_accuracy_from_oof(y_true, oof_probs):
    best = -1
    for t in np.linspace(0.6, 0.95, 200):
        best = max(best, balanced_accuracy_score(y_true, (oof_probs >= t).astype(int)))
    return best

def objective(trial):
    params = {
        "bootstrap_type": "Bernoulli",   # 🔥 быстрее и стабильнее
        "iterations": trial.suggest_int("iterations", 1800, 2800),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.04, log=True),
        "depth": trial.suggest_int("depth", 7, 11),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 5, 25),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 20, 100),
        "random_strength": trial.suggest_float("random_strength", 0.5, 2.0),
        "subsample": trial.suggest_float("subsample", 0.6, 0.9),
        "scale_pos_weight": trial.suggest_float("scale_pos_weight", 5.0, 10.0),

        "task_type": "GPU",
        "devices": "0",
        "loss_function": "Logloss",
        "eval_metric": "Logloss",
        "random_seed": 42,
        "verbose": False,
    }

    oof = np.zeros(len(X_cb))

    for tr_idx, val_idx in CV.split(X_cb, y):
        model = CatBoostClassifier(**params)
        model.fit(
            X_cb.iloc[tr_idx], y.iloc[tr_idx],
            cat_features=cat_cols,
            eval_set=(X_cb.iloc[val_idx], y.iloc[val_idx]),
            early_stopping_rounds=100,
            verbose=False
        )
        oof[val_idx] = model.predict_proba(X_cb.iloc[val_idx])[:, 1]

    return best_balanced_accuracy_from_oof(y, oof)

study = optuna.create_study(direction="maximize", sampler=TPESampler(seed=42))
study.optimize(objective, n_trials=8, show_progress_bar=True)

print("Best OOF BA:", study.best_value)
print("Best params:", study.best_params)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Best OOF BA: 0.7435966057441253
# Best params: {'iterations': 1888, 'learning_rate': 0.013121800797993606, 'depth': 7, 'l2_leaf_reg': 11, 'min_data_in_leaf': 51, 'random_strength': 0.9070235476608439, 'subsample': 0.8486212527455788, 'scale_pos_weight': 6.7837666334679465}

# %% [markdown]
# # CatBoost

# %%
X_cb = X_cb.reset_index(drop=True)
y = y.reset_index(drop=True)

CV_FINAL = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

best_params = study.best_params.copy()
best_params["scale_pos_weight"] = 1.0


best_params.update({
    "bootstrap_type": "Bernoulli",
    "task_type": "GPU",
    "devices": "0",
    "loss_function": "Logloss",
    "eval_metric": "Logloss",
    "random_seed": 42,
    "verbose": False,
    "od_type": "Iter",
})


oof_probs = np.zeros(len(X_cb), dtype=float)
models = []

for fold, (tr_idx, val_idx) in enumerate(CV_FINAL.split(X_cb, y), start=1):
    model = CatBoostClassifier(**best_params)
    model.fit(
        X_cb.iloc[tr_idx], y.iloc[tr_idx],
        cat_features=cat_cols,
        eval_set=(X_cb.iloc[val_idx], y.iloc[val_idx]),
        early_stopping_rounds=150,
        verbose=False
    )
    proba = model.predict_proba(X_cb.iloc[val_idx])[:, 1]
    oof_probs[val_idx] = proba
    models.append(model)
    print(f"Fold {fold} | AUC:", roc_auc_score(y.iloc[val_idx], proba))

best_th, best_bal = 0.5, -1.0
for t in np.linspace(0.05, 0.95, 181):
    bal = balanced_accuracy_score(y, (oof_probs >= t).astype(int))
    if bal > best_bal:
        best_bal, best_th = float(bal), float(t)

print("OOF AUC:", roc_auc_score(y, oof_probs))
print("Best threshold:", best_th)
print("Best OOF balanced accuracy:", best_bal)
# Out:
# Fold 1 | AUC: 0.7646103896103896
# Fold 2 | AUC: 0.8909090909090908
# Fold 3 | AUC: 0.7629870129870129
# Fold 4 | AUC: 0.7907894736842106
# Fold 5 | AUC: 0.8157894736842105
# OOF AUC: 0.8100783289817232
# Best threshold: 0.72
# Best OOF balanced accuracy: 0.7524281984334205

# %% [markdown]
# # LightGBM (LightGBM - OOF-оценка для ансамблирования)

# %%
# подготовка данных под LGBM
X_lgb = X.copy()

# категории как category
for c in cat_cols:
    X_lgb[c] = X_lgb[c].astype("category")

X_lgb = X_lgb.reset_index(drop=True)
y_lgb = y.reset_index(drop=True)

# OOF для LGBM
CV = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
oof_probs_lgb = np.zeros(len(X_lgb))

for fold, (tr_idx, val_idx) in enumerate(CV.split(X_lgb, y_lgb), start=1):
    model = lgb.LGBMClassifier(
        n_estimators=2000,
        learning_rate=0.02,
        num_leaves=64,
        max_depth=-1,
        min_child_samples=30,
        subsample=0.8,
        colsample_bytree=0.8,
        objective="binary",
        class_weight=None,   
        random_state=42
    )

    model.fit(
        X_lgb.iloc[tr_idx], y_lgb.iloc[tr_idx],
        eval_set=[(X_lgb.iloc[val_idx], y_lgb.iloc[val_idx])],
        eval_metric="auc",
        callbacks=[lgb.early_stopping(100, verbose=False)]
    )

    proba = model.predict_proba(X_lgb.iloc[val_idx])[:, 1]
    oof_probs_lgb[val_idx] = proba

    print(f"Fold {fold} | LGB AUC:", roc_auc_score(y_lgb.iloc[val_idx], proba))

# корреляция
corr = np.corrcoef(oof_probs, oof_probs_lgb)[0, 1]
print("\nCorr(CatBoost, LGBM) =", round(corr, 4))

print("CatBoost OOF mean:", oof_probs.mean())
print("LGBM OOF mean:", oof_probs_lgb.mean())
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 306, number of negative: 160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000075 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1378
# [LightGBM] [Info] Number of data points in the train set: 466, number of used features: 19
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.656652 -> initscore=0.648411
# [LightGBM] [Info] Start training from score 0.648411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Fold 1 | LGB AUC: 0.8146103896103895
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 306, number of negative: 160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000065 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1375
# [LightGBM] [Info] Number of data points in the train set: 466, number of used features: 19
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.656652 -> initscore=0.648411
# [LightGBM] [Info] Start training from score 0.648411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Fold 2 | LGB AUC: 0.885064935064935
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 306, number of negative: 160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000081 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1377
# [LightGBM] [Info] Number of data points in the train set: 466, number of used features: 19
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.656652 -> initscore=0.648411
# [LightGBM] [Info] Start training from score 0.648411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Fold 3 | LGB AUC: 0.7873376623376623
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 307, number of negative: 160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1380
# [LightGBM] [Info] Number of data points in the train set: 467, number of used features: 19
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.657388 -> initscore=0.651674
# [LightGBM] [Info] Start training from score 0.651674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Fold 4 | LGB AUC: 0.8074013157894737
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 307, number of negative: 160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000062 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1381
# [LightGBM] [Info] Number of data points in the train set: 467, number of used features: 19
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.657388 -> initscore=0.651674
# [LightGBM] [Info] Start training from score 0.651674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Fold 5 | LGB AUC: 0.831578947368421
#
# Corr(CatBoost, LGBM) = 0.751
# CatBoost OOF mean: 0.6489528453240924
# LGBM OOF mean: 0.6559851529344733

# %% [markdown]
# # LightGBM (LightGBM (модели для получения тестовых вероятностей))

# %%
# LGBM для тройного блендирования

X_lgb = X.copy()
for c in cat_cols:
    X_lgb[c] = X_lgb[c].astype("category")

X_lgb = X_lgb.reset_index(drop=True)
y_lgb = y.reset_index(drop=True)

CV = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

models_lgb = []

lgb_params = dict(
    n_estimators=4000,
    learning_rate=0.01,
    num_leaves=63,
    min_child_samples=10,
    subsample=0.9,
    colsample_bytree=0.9,
    reg_lambda=1.0,
    objective="binary",
    random_state=42
)

for fold, (tr_idx, val_idx) in enumerate(CV.split(X_lgb, y_lgb), start=1):
    m = lgb.LGBMClassifier(**lgb_params)
    m.fit(
        X_lgb.iloc[tr_idx], y_lgb.iloc[tr_idx],
        eval_set=[(X_lgb.iloc[val_idx], y_lgb.iloc[val_idx])],
        eval_metric="auc",
        callbacks=[lgb.early_stopping(200, verbose=False)]
    )
    models_lgb.append(m)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 306, number of negative: 160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000068 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1378
# [LightGBM] [Info] Number of data points in the train set: 466, number of used features: 19
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.656652 -> initscore=0.648411
# [LightGBM] [Info] Start training from score 0.648411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 306, number of negative: 160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1375
# [LightGBM] [Info] Number of data points in the train set: 466, number of used features: 19
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.656652 -> initscore=0.648411
# [LightGBM] [Info] Start training from score 0.648411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 306, number of negative: 160
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1377
# [LightGBM] [Info] Number of data points in the train set: 466, number of used features: 19
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.656652 -> initscore=0.648411
# [LightGBM] [Info] Start training from score 0.648411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# # XGBoost

# %%
X_xgb = X.copy()

# категории в category
for c in cat_cols:
    X_xgb[c] = X_xgb[c].astype("category")

X_xgb = X_xgb.reset_index(drop=True)
y_xgb = y.reset_index(drop=True)

# убираем inf / -inf / очень большие 
X_xgb = X_xgb.replace([np.inf, -np.inf], np.nan)

# обрезаем числовые значения
num_cols = X_xgb.select_dtypes(include=["number"]).columns
X_xgb[num_cols] = X_xgb[num_cols].clip(-1e6, 1e6)

# контроль
bad = np.isinf(X_xgb[num_cols].to_numpy()).any() or np.isnan(X_xgb[num_cols].to_numpy()).sum() > 0
print("Has inf:", np.isinf(X_xgb[num_cols].to_numpy()).any())
print("NaN count:", np.isnan(X_xgb[num_cols].to_numpy()).sum())

CV = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
oof_probs_xgb = np.zeros(len(X_xgb), dtype=float)

params = {
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "max_depth": 6,
    "eta": 0.05,
    "subsample": 0.8,
    "colsample_bytree": 0.8,

    "tree_method": "hist",   
    "device": "cuda",        
    "max_cat_to_onehot": 16,
    "random_state": 42,
}


for fold, (tr_idx, val_idx) in enumerate(CV.split(X_xgb, y_xgb), start=1):
    dtrain = xgb.DMatrix(
        X_xgb.iloc[tr_idx],
        label=y_xgb.iloc[tr_idx],
        enable_categorical=True,
        missing=np.nan
    )
    dval = xgb.DMatrix(
        X_xgb.iloc[val_idx],
        label=y_xgb.iloc[val_idx],
        enable_categorical=True,
        missing=np.nan
    )

    model = xgb.train(
        params,
        dtrain,
        num_boost_round=800,
        evals=[(dval, "val")],
        verbose_eval=False
    )

    proba = model.predict(dval)
    oof_probs_xgb[val_idx] = proba
    print(f"Fold {fold} | XGB AUC:", roc_auc_score(y_xgb.iloc[val_idx], proba))

print("XGB oof mean:", oof_probs_xgb.mean())
# Out:
# Has inf: False
# NaN count: 75
# Fold 1 | XGB AUC: 0.7275974025974026
# Fold 2 | XGB AUC: 0.8655844155844156
# Fold 3 | XGB AUC: 0.7659090909090909
# Fold 4 | XGB AUC: 0.7539473684210526
# Fold 5 | XGB AUC: 0.8
# XGB oof mean: 0.6790015234064397

# %% [markdown]
# # Проверка корреляций моделей

# %%
print("Corr(CB, LGB) =", np.corrcoef(oof_probs, oof_probs_lgb)[0,1])
print("Corr(CB, XGB) =", np.corrcoef(oof_probs, oof_probs_xgb)[0,1])
print("Corr(LGB, XGB) =", np.corrcoef(oof_probs_lgb, oof_probs_xgb)[0,1])
# Out:
# Corr(CB, LGB) = 0.7509769398079695
# Corr(CB, XGB) = 0.8032670130498449
# Corr(LGB, XGB) = 0.5946609162098111

# %% [markdown]
# # Inference: LightGBM (test probabilities)

# %%
test_lgb = df_test[X.columns].copy()
for c in cat_cols:
    test_lgb[c] = test_lgb[c].fillna("Unknown").astype("category")

test_probs_lgb = np.mean([m.predict_proba(test_lgb)[:,1] for m in models_lgb], axis=0)
print("test_probs_lgb mean:", test_probs_lgb.mean())

# %% [markdown]
# # Ensembling: OOF-based weight & threshold search

# %%
from sklearn.metrics import balanced_accuracy_score

p_cb  = oof_probs.copy()
p_lgb = oof_probs_lgb.copy()
p_xgb = oof_probs_xgb.copy()
y_true = y.values if hasattr(y, "values") else np.asarray(y)

def search_weights_and_threshold(y_true, p_cb, p_lgb, p_xgb,
                                 step_w=0.02, th_grid=np.linspace(0.05, 0.95, 181)):
    best = (-1.0, None, None, None)  # (BA, w_cb, w_lgb, th)
    # w_cb + w_lgb + w_xgb = 1
    for w_cb in np.arange(0.0, 1.0 + 1e-9, step_w):
        for w_lgb in np.arange(0.0, 1.0 - w_cb + 1e-9, step_w):
            w_xgb = 1.0 - w_cb - w_lgb
            if w_xgb < -1e-9: 
                continue
            p = w_cb*p_cb + w_lgb*p_lgb + w_xgb*p_xgb

            # лучший порог для этих весов
            for th in th_grid:
                pred = (p >= th).astype(int)
                ba = balanced_accuracy_score(y_true, pred)
                if ba > best[0]:
                    best = (float(ba), float(w_cb), float(w_lgb), float(th))
    return best

best_ba, w_cb, w_lgb, best_th = search_weights_and_threshold(
    y_true, p_cb, p_lgb, p_xgb,
    step_w=0.02,
    th_grid=np.linspace(0.50, 0.85, 351)
)

w_xgb = 1.0 - w_cb - w_lgb

print("Best OOF BA (triple blend):", best_ba)
print("Weights: w_cb =", round(w_cb,3), "| w_lgb =", round(w_lgb,3), "| w_xgb =", round(w_xgb,3))
print("Best threshold:", round(best_th,3))
# Out:
# Best OOF BA (triple blend): 0.7585117493472584
# Weights: w_cb = 0.04 | w_lgb = 0.84 | w_xgb = 0.12
# Best threshold: 0.699

# %% [markdown]
# # Inference: CatBoost (test probabilities)

# %%
test_cb = df_test[X.columns].copy()
for c in cat_cols:
    test_cb[c] = test_cb[c].astype("object").where(test_cb[c].notna(), "Unknown").astype(str)

test_probs_cb = np.mean([m.predict_proba(test_cb)[:,1] for m in models], axis=0)
print("test_probs_cb mean:", test_probs_cb.mean())
# Out:
# test_probs_cb mean: 0.6210514602332036

# %% [markdown]
# # Inference: XGBoost (models + test probabilities)

# %%
# готовим XGB test
test_xgb = df_test[X.columns].copy()
for c in cat_cols:
    test_xgb[c] = test_xgb[c].fillna("Unknown").astype("category")

test_xgb = test_xgb.replace([np.inf, -np.inf], np.nan)
num_cols = test_xgb.select_dtypes(include=["number"]).columns
test_xgb[num_cols] = test_xgb[num_cols].clip(-1e6, 1e6)

models_xgb = []
CV = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

params = {
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "max_depth": 6,
    "eta": 0.05,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "tree_method": "hist",
    "device": "cuda",  
    "max_cat_to_onehot": 16,
    "random_state": 42,
}

for tr_idx, val_idx in CV.split(X_xgb, y_xgb):
    dtrain = xgb.DMatrix(X_xgb.iloc[tr_idx], label=y_xgb.iloc[tr_idx], enable_categorical=True, missing=np.nan)
    dval   = xgb.DMatrix(X_xgb.iloc[val_idx], label=y_xgb.iloc[val_idx], enable_categorical=True, missing=np.nan)

    m = xgb.train(
        params,
        dtrain,
        num_boost_round=800,
        evals=[(dval, "val")],
        verbose_eval=False
    )
    models_xgb.append(m)

# test probs xgb
dtest = xgb.DMatrix(test_xgb, enable_categorical=True, missing=np.nan)
test_probs_xgb = np.mean([m.predict(dtest) for m in models_xgb], axis=0)
print("test_probs_xgb mean:", test_probs_xgb.mean())
# Out:
# test_probs_xgb mean: 0.57971257

# %% [markdown]
# # Shap, roc_auc

# %%
import shap

# Подготовка данных
X_shap = X_cb.copy()
for c in cat_cols:
    X_shap[c] = X_shap[c].astype("object").where(X_shap[c].notna(), "Unknown").astype(str)

# Обучаем финальную модель на всём train
final_model = CatBoostClassifier(**best_params)
final_model.fit(X_shap, y, cat_features=cat_cols, verbose=False)

# %%
# SHAP explainer
explainer = shap.TreeExplainer(final_model)

# SHAP values для всего train
shap_values = explainer.shap_values(X_shap)

# base value
base_value = explainer.expected_value

# Собираем Explanation
exp = shap.Explanation(
    values=shap_values,
    base_values=np.full(len(X_shap), base_value),
    data=X_shap.values,
    feature_names=X_shap.columns.tolist()
)

# BAR PLOT (global importance)
fig, ax = plt.subplots(figsize=(12,6))
shap.plots.bar(
    exp,
    max_display=15,
    show=False
)
plt.tight_layout()
plt.savefig('my_sin_plot.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
shap.plots.beeswarm(
    exp,
    max_display=19,
    plot_size=(12, 6),
    show=False
)
plt.tight_layout()
plt.savefig('my_sin_plot.png')
plt.show()
# Out:
# C:\Users\knefpc\miniconda3\envs\jupgpu\lib\site-packages\numpy\lib\_function_base_impl.py:4653: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
test_probs_blend = w_cb*test_probs_cb + w_lgb*test_probs_lgb + (1.0-w_cb-w_lgb)*test_probs_xgb

# сделаем несколько сабмитов вокруг best_th
ths = [best_th-0.03, best_th-0.02, best_th-0.01, best_th, best_th+0.01, best_th+0.02, best_th+0.03]
ths = [float(np.clip(t, 0.05, 0.95)) for t in ths]

for t in ths:
    pred = (test_probs_blend >= t).astype(int)
    sub = pd.DataFrame({"ID": np.arange(1, len(pred)+1), "target": pred})
    fname = f"submission_triple_wcb{w_cb:.2f}_wlgb{w_lgb:.2f}_t{t:.3f}.csv"
    sub.to_csv(fname, index=False)
    print("Saved:", fname, "| positives=", round(pred.mean(), 3))
# Out:
# Saved: submission_triple_wcb0.04_wlgb0.84_t0.669.csv | positives= 0.477
# Saved: submission_triple_wcb0.04_wlgb0.84_t0.679.csv | positives= 0.455
# Saved: submission_triple_wcb0.04_wlgb0.84_t0.689.csv | positives= 0.432
# Saved: submission_triple_wcb0.04_wlgb0.84_t0.699.csv | positives= 0.409
# Saved: submission_triple_wcb0.04_wlgb0.84_t0.709.csv | positives= 0.409
# Saved: submission_triple_wcb0.04_wlgb0.84_t0.719.csv | positives= 0.364
# Saved: submission_triple_wcb0.04_wlgb0.84_t0.729.csv | positives= 0.364

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# ROC по OOF-предсказаниям
fpr, tpr, _ = roc_curve(y, oof_probs)
roc_auc = roc_auc_score(y, oof_probs)

plt.figure(figsize=(6, 6), dpi=150)

plt.plot(
    fpr, tpr,
    color="darkorange",
    lw=2,
    label=f"ROC curve (AUC = {roc_auc:.3f})"
)

# Линия случайного угадывания
plt.plot([0, 1], [0, 1], linestyle="--", color="gray", lw=1)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC curve (OOF predictions)")
plt.legend(loc="lower right")



plt.tight_layout()

plt.savefig('my_sin_plot.png')

plt.show()

# %%
row_id = 0

exp_one = shap.Explanation(
    values=shap_values[row_id],
    base_values=base_value,
    data=X_shap.iloc[row_id].values,
    feature_names=X_shap.columns.tolist()
)

plt.figure()
shap.plots.waterfall(
    exp_one,
    max_display=15,
    show=False
)
plt.title(f"Local SHAP explanation (row {row_id})")
plt.tight_layout()
plt.savefig('my_sin_plot.png')

plt.show()

# %%
row_id = 100

exp_one = shap.Explanation(
    values=shap_values[row_id],
    base_values=base_value,
    data=X_shap.iloc[row_id].values,
    feature_names=X_shap.columns.tolist()
)

plt.figure()
shap.plots.waterfall(
    exp_one,
    max_display=15,
    show=False
)
plt.title(f"Local SHAP explanation (row {row_id})")
plt.tight_layout()
plt.savefig('my_sin_plot.png')

plt.show()

# %%
row_id = 200

exp_one = shap.Explanation(
    values=shap_values[row_id],
    base_values=base_value,
    data=X_shap.iloc[row_id].values,
    feature_names=X_shap.columns.tolist()
)

plt.figure()
shap.plots.waterfall(
    exp_one,
    max_display=15,
    show=False
)
plt.title(f"Local SHAP explanation (row {row_id})")
plt.tight_layout()
plt.savefig('my_sin_plot.png')

plt.show()

# %%
row_id = 50

exp_one = shap.Explanation(
    values=shap_values[row_id],
    base_values=base_value,
    data=X_shap.iloc[row_id].values,
    feature_names=X_shap.columns.tolist()
)

plt.figure()
shap.plots.waterfall(
    exp_one,
    max_display=15,
    show=False
)
plt.title(f"Local SHAP explanation (row {row_id})")
plt.tight_layout()
plt.savefig('my_sin_plot.png')

plt.show()
